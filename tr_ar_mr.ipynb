# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('price_quantity.csv')
df=pd.DataFrame(data)
df
# Out:
#    Quantity  Price
# 0         1    100
# 1         2     95
# 2         3     90
# 3         4     85
# 4         5     80
# 5         6     75
# 6         7     70
# 7         8     65

# %% [markdown]
# Calculations

# %%
df['TR']=df["Quantity"]*df['Price']
df['AR']=(df['TR']/df['Quantity']).astype(int)
df['MR']=df['TR'].diff()/df["Quantity"].diff()
df
# Out:
#    Quantity  Price   TR   AR    MR
# 0         1    100  100  100   NaN
# 1         2     95  190   95  90.0
# 2         3     90  270   90  80.0
# 3         4     85  340   85  70.0
# 4         5     80  400   80  60.0
# 5         6     75  450   75  50.0
# 6         7     70  490   70  40.0
# 7         8     65  520   65  30.0

# %% [markdown]
# Ploting

# %%
print(df)
plt.figure(figsize=(10,5))
sns.lineplot(data=df,x="Quantity",y="TR",marker='o',label="TR")
sns.lineplot(data=df,x="Quantity",y="AR",marker='o',label="AR")
sns.lineplot(data=df,x="Quantity",y="MR",marker='o',label="MR")
plt.grid(True)
plt.title("TR, AR and MR Curves")
plt.xlabel("Quantity")
plt.ylabel("Revenue")
plt.legend()
plt.show()
# Out:
#    Quantity  Price   TR   AR    MR
# 0         1    100  100  100   NaN
# 1         2     95  190   95  90.0
# 2         3     90  270   90  80.0
# 3         4     85  340   85  70.0
# 4         5     80  400   80  60.0
# 5         6     75  450   75  50.0
# 6         7     70  490   70  40.0
# 7         8     65  520   65  30.0
